# %%
import numpy as np
import cv2
import os
import pandas as pd

# %%
data = pd.read_csv('/gdrive/My Drive/FaceDetection/data/fer2013.csv')
train_set = data[(data.Usage == 'Training')]
validation_set = data[(data.Usage == 'PublicTest')]
test_set = data[(data.Usage == 'PrivateTest')]

# %%
angry_train = train_set.loc[train_set['emotion'] == 0]
angry_test = test_set.loc[test_set['emotion'] == 0]
angry_val = validation_set.loc[validation_set['emotion'] == 0]

disgust_train = train_set.loc[train_set['emotion'] == 1]
disgust_test = test_set.loc[test_set['emotion'] == 1]
disgust_val = validation_set.loc[validation_set['emotion'] == 1]

fear_train = train_set.loc[train_set['emotion'] == 2]
fear_test = test_set.loc[test_set['emotion'] == 2]
fear_val = validation_set.loc[validation_set['emotion'] == 2]

happy_train = train_set.loc[train_set['emotion'] == 3]
happy_test = test_set.loc[test_set['emotion'] == 3]
happy_val = validation_set.loc[validation_set['emotion'] == 3]

sad_train = train_set.loc[train_set['emotion'] == 4]
sad_test = test_set.loc[test_set['emotion'] == 4]
sad_val = validation_set.loc[validation_set['emotion'] == 4]

surprise_train = train_set.loc[train_set['emotion'] == 5]
surprise_test = test_set.loc[test_set['emotion'] == 5]
surprise_val = validation_set.loc[validation_set['emotion'] == 5]

normal_train = train_set.loc[train_set['emotion'] == 6]
normal_test = test_set.loc[test_set['emotion'] == 6]
normal_val = validation_set.loc[validation_set['emotion'] == 6]

# %%
count = 0
angry_train = np.array(angry_train)
for row in angry_train:
  pixels=np.asarray(list(row[1].split(' ')),dtype=np.uint8)
  img=pixels.reshape((48,48))
  pathname='/gdrive/My Drive/FaceDetection/Train/angry/'+str(count)+'.jpg'
  cv2.imwrite(pathname,img)
  print('image saved ias {}'.format(pathname))
  count = count + 1

count = 0
angry_test = np.array(angry_test)
for row in angry_test:
  pixels=np.asarray(list(row[1].split(' ')),dtype=np.uint8)
  img=pixels.reshape((48,48))
  pathname='/gdrive/My Drive/FaceDetection/Test/angry/'+str(count)+'.jpg'
  cv2.imwrite(pathname,img)
  print('image saved ias {}'.format(pathname))
  count = count + 1

count = 0
angry_val = np.array(angry_val)
for row in angry_val:
  pixels=np.asarray(list(row[1].split(' ')),dtype=np.uint8)
  img=pixels.reshape((48,48))
  pathname='/gdrive/My Drive/FaceDetection/Val/angry/'+ str(count)+'.jpg'
  cv2.imwrite(pathname,img)
  print('image saved ias {}'.format(pathname))
  count = count + 1
#_________________________________disgust_______________________________________________
count = 0
disgust_train = np.array(disgust_train)
for row in disgust_train:
  pixels=np.asarray(list(row[1].split(' ')),dtype=np.uint8)
  img=pixels.reshape((48,48))
  pathname='/gdrive/My Drive/FaceDetection/Train/disgust/'+str(count)+'.jpg'
  cv2.imwrite(pathname,img)
  print('image saved ias {}'.format(pathname))
  count = count + 1

count = 0
disgust_test = np.array(disgust_test)
for row in disgust_test:
  pixels=np.asarray(list(row[1].split(' ')),dtype=np.uint8)
  img=pixels.reshape((48,48))
  pathname='/gdrive/My Drive/FaceDetection/Test/disgust/'+str(count)+'.jpg'
  cv2.imwrite(pathname,img)
  print('image saved ias {}'.format(pathname))
  count = count + 1

count = 0
disgust_val = np.array(disgust_val)
for row in disgust_val:
  pixels=np.asarray(list(row[1].split(' ')),dtype=np.uint8)
  img=pixels.reshape((48,48))
  pathname='/gdrive/My Drive/FaceDetection/Val/disgust/'+ str(count)+'.jpg'
  cv2.imwrite(pathname,img)
  print('image saved ias {}'.format(pathname))
  count = count + 1
#_______________________________fear_________________________________________________
count = 0
fear_train = np.array(fear_train)
for row in fear_train:
  pixels=np.asarray(list(row[1].split(' ')),dtype=np.uint8)
  img=pixels.reshape((48,48))
  pathname='/gdrive/My Drive/FaceDetection/Train/fear/'+str(count)+'.jpg'
  cv2.imwrite(pathname,img)
  print('image saved ias {}'.format(pathname))
  count = count + 1

count = 0
fear_test = np.array(fear_test)
for row in fear_test:
  pixels=np.asarray(list(row[1].split(' ')),dtype=np.uint8)
  img=pixels.reshape((48,48))
  pathname='/gdrive/My Drive/FaceDetection/Test/fear/'+str(count)+'.jpg'
  cv2.imwrite(pathname,img)
  print('image saved ias {}'.format(pathname))
  count = count + 1

count = 0
fear_val = np.array(fear_val)
for row in fear_val:
  pixels=np.asarray(list(row[1].split(' ')),dtype=np.uint8)
  img=pixels.reshape((48,48))
  pathname='/gdrive/My Drive/FaceDetection/Val/fear/'+ str(count)+'.jpg'
  cv2.imwrite(pathname,img)
  print('image saved ias {}'.format(pathname))
  count = count + 1
#____________________________happy____________________________________________________
count = 0
happy_train = np.array(happy_train)
for row in happy_train:
  pixels=np.asarray(list(row[1].split(' ')),dtype=np.uint8)
  img=pixels.reshape((48,48))
  pathname='/gdrive/My Drive/FaceDetection/Train/happy/'+str(count)+'.jpg'
  cv2.imwrite(pathname,img)
  print('image saved ias {}'.format(pathname))
  count = count + 1

count = 0
happy_test = np.array(happy_test)
for row in happy_test:
  pixels=np.asarray(list(row[1].split(' ')),dtype=np.uint8)
  img=pixels.reshape((48,48))
  pathname='/gdrive/My Drive/FaceDetection/Test/happy/'+str(count)+'.jpg'
  cv2.imwrite(pathname,img)
  print('image saved ias {}'.format(pathname))
  count = count + 1

count = 0
happy_val = np.array(happy_val)
for row in happy_val:
  pixels=np.asarray(list(row[1].split(' ')),dtype=np.uint8)
  img=pixels.reshape((48,48))
  pathname='/gdrive/My Drive/FaceDetection/Val/happy/'+ str(count)+'.jpg'
  cv2.imwrite(pathname,img)
  print('image saved ias {}'.format(pathname))
  count = count + 1
#_____________________________normal___________________________________________________
count = 0
normal_train = np.array(normal_train)
for row in normal_train:
  pixels=np.asarray(list(row[1].split(' ')),dtype=np.uint8)
  img=pixels.reshape((48,48))
  pathname='/gdrive/My Drive/FaceDetection/Train/normal/'+str(count)+'.jpg'
  cv2.imwrite(pathname,img)
  print('image saved ias {}'.format(pathname))
  count = count + 1

count = 0
normal_test = np.array(normal_test)
for row in normal_test:
  pixels=np.asarray(list(row[1].split(' ')),dtype=np.uint8)
  img=pixels.reshape((48,48))
  pathname='/gdrive/My Drive/FaceDetection/Test/normal/'+str(count)+'.jpg'
  cv2.imwrite(pathname,img)
  print('image saved ias {}'.format(pathname))
  count = count + 1

count = 0
normal_val = np.array(normal_val)
for row in normal_val:
  pixels=np.asarray(list(row[1].split(' ')),dtype=np.uint8)
  img=pixels.reshape((48,48))
  pathname='/gdrive/My Drive/FaceDetection/Val/normal/'+ str(count)+'.jpg'
  cv2.imwrite(pathname,img)
  print('image saved ias {}'.format(pathname))
  count = count + 1
# Out:
# Streaming output truncated to the last 5000 lines.
# image saved ias /gdrive/My Drive/FaceDetection/Train/normal/1199.jpg
# image saved ias /gdrive/My Drive/FaceDetection/Train/normal/1200.jpg
# image saved ias /gdrive/My Drive/FaceDetection/Train/normal/1201.jpg
# image saved ias /gdrive/My Drive/FaceDetection/Train/normal/1202.jpg
# image saved ias /gdrive/My Drive/FaceDetection/Train/normal/1203.jpg
# image saved ias /gdrive/My Drive/FaceDetection/Train/normal/1204.jpg
# image saved ias /gdrive/My Drive/FaceDetection/Train/normal/1205.jpg
# image saved ias /gdrive/My Drive/FaceDetection/Train/normal/1206.jpg
# image saved ias /gdrive/My Drive/FaceDetection/Train/normal/1207.jpg
# image saved ias /gdrive/My Drive/FaceDetection/Train/normal/1208.jpg
# image saved ias /gdrive/My Drive/FaceDetection/Train/normal/1209.jpg
# image saved ias /gdrive/My Drive/FaceDetection/Train/normal/1210.jpg
# image saved ias /gdrive/My Drive/FaceDetection/Train/normal/1211.jpg
# ...

# %%
#_________________________________sad_______________________________________________
count = 0
sad_train = np.array(sad_train)
for row in sad_train:
  pixels=np.asarray(list(row[1].split(' ')),dtype=np.uint8)
  img=pixels.reshape((48,48))
  pathname='/gdrive/My Drive/FaceDetection/Train/sad/'+str(count)+'.jpg'
  cv2.imwrite(pathname,img)
  print('image saved ias {}'.format(pathname))
  count = count + 1

count = 0
sad_test = np.array(sad_test)
for row in sad_test:
  pixels=np.asarray(list(row[1].split(' ')),dtype=np.uint8)
  img=pixels.reshape((48,48))
  pathname='/gdrive/My Drive/FaceDetection/Test/sad/'+ str(count)+'.jpg'
  cv2.imwrite(pathname,img)
  print('image saved ias {}'.format(pathname))
  count = count + 1

count = 0
sad_val = np.array(sad_val)
for row in sad_val:
  pixels=np.asarray(list(row[1].split(' ')),dtype=np.uint8)
  img=pixels.reshape((48,48))
  pathname='/gdrive/My Drive/FaceDetection/Val/sad/'+ str(count)+'.jpg'
  var = cv2.imwrite(pathname,img)
  print(var)
  if var is False:
    print('immagine non salvata')
  print('image saved ias {}'.format(pathname))
  count = count + 1

# %%
#__________________________surprise______________________________________________________
count = 0
surprise_train = np.array(surprise_train)
for row in surprise_train:
  pixels=np.asarray(list(row[1].split(' ')),dtype=np.uint8)
  img=pixels.reshape((48,48))
  pathname='/gdrive/My Drive/FaceDetection/Train/surprise/'+str(count)+'.jpg'
  print('image saved ias {}'.format(pathname))
  cv2.imwrite(pathname,img)
  #print('image saved ias {}'.format(pathname))
  count = count + 1

count = 0
surprise_val = np.array(surprise_val)
for row in surprise_val:
  pixels=np.asarray(list(row[1].split(' ')),dtype=np.uint8)
  img=pixels.reshape((48,48))
  pathname='/gdrive/My Drive/FaceDetection/Val/surprise/'+ str(count)+'.jpg'
  print('image saved ias {}'.format(pathname))
  cv2.imwrite(pathname,img)
 #print('image saved ias {}'.format(pathname))
  count = count + 1

count = 0
surprise_test = np.array(surprise_test)
for row in surprise_test:
  pixels=np.asarray(list(row[1].split(' ')),dtype=np.uint8)
  img=pixels.reshape((48,48))
  pathname='/gdrive/My Drive/FaceDetection/Test/surprise/'+ str(count)+'.jpg'
  print('image saved ias {}'.format(pathname))
  cv2.imwrite(pathname, img)
  #print('image saved ias {}'.format(pathname))
  count = count + 1
# Out:
# image saved ias /gdrive/My Drive/FaceDetection/Train/surprise/0.jpg
# image saved ias /gdrive/My Drive/FaceDetection/Train/surprise/1.jpg
# image saved ias /gdrive/My Drive/FaceDetection/Train/surprise/2.jpg
# image saved ias /gdrive/My Drive/FaceDetection/Train/surprise/3.jpg
# image saved ias /gdrive/My Drive/FaceDetection/Train/surprise/4.jpg
# image saved ias /gdrive/My Drive/FaceDetection/Train/surprise/5.jpg
# image saved ias /gdrive/My Drive/FaceDetection/Train/surprise/6.jpg
# image saved ias /gdrive/My Drive/FaceDetection/Train/surprise/7.jpg
# image saved ias /gdrive/My Drive/FaceDetection/Train/surprise/8.jpg
# image saved ias /gdrive/My Drive/FaceDetection/Train/surprise/9.jpg
# image saved ias /gdrive/My Drive/FaceDetection/Train/surprise/10.jpg
# image saved ias /gdrive/My Drive/FaceDetection/Train/surprise/11.jpg
# image saved ias /gdrive/My Drive/FaceDetection/Train/surprise/12.jpg
# image saved ias /gdrive/My Drive/FaceDetection/Train/surprise/13.jpg
# ...
